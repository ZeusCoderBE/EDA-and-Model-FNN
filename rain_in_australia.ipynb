# %% [markdown]
# ## 1.Import Libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error,f1_score,recall_score,accuracy_score,confusion_matrix, roc_curve, roc_auc_score
import tensorflow as tf
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2.Exploratory Data Analys

# %% [markdown]
# ### 2.1 Import DataSet

# %%
# Reading the data
df_weather = pd.read_csv('weatherAUS.csv')
df_weather.head(5)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %%
df_weather.shape
# Out:
# (145460, 23)

# %%
df_weather.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %% [markdown]
# > Bộ dữ liệu này chứa khoảng 10 năm quan sát thời tiết hàng ngày từ nhiều địa điểm trên khắp nước Úc bao gồm 145460 và 23 thuộc tính
#
# > RainTomorrow là biến mục tiêu cần cho bài toán phân loại.

# %% [markdown]
# ### 2.2 Structure of dataset

# %%
# Checking the data types
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
#  16  Pressure3pm    130432 non-null  float64
#  17  Cloud9am       89572 non-null   float64
#  18  Cloud3pm       86102 non-null   float64
#  19  Temp9am        143693 non-null  float64
#  20  Temp3pm        141851 non-null  float64
#  21  RainToday      142199 non-null  object
#  22  RainTomorrow   142193 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 25.5+ MB

# %% [markdown]
# ### 2.3 Summary of statistic

# %%
df_weather.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# 25%        4.800000      31.000000       7.000000      13.000000
# 50%        8.400000      39.000000      13.000000      19.000000
# 75%       10.600000      48.000000      19.000000      24.000000
# max       14.500000     135.000000     130.000000      87.000000
#
#          Humidity9am    Humidity3pm   Pressure9am    Pressure3pm  \
# count  142806.000000  140953.000000  130395.00000  130432.000000
# mean       68.880831      51.539116    1017.64994    1015.255889
# std        19.029164      20.795902       7.10653       7.037414
# min         0.000000       0.000000     980.50000     977.100000
# 25%        57.000000      37.000000    1012.90000    1010.400000
# 50%        70.000000      52.000000    1017.60000    1015.200000
# 75%        83.000000      66.000000    1022.40000    1020.000000
# max       100.000000     100.000000    1041.00000    1039.600000
#
#            Cloud9am      Cloud3pm        Temp9am       Temp3pm
# count  89572.000000  86102.000000  143693.000000  141851.00000
# mean       4.447461      4.509930      16.990631      21.68339
# std        2.887159      2.720357       6.488753       6.93665
# min        0.000000      0.000000      -7.200000      -5.40000
# 25%        1.000000      2.000000      12.300000      16.60000
# 50%        5.000000      5.000000      16.700000      21.10000
# 75%        7.000000      7.000000      21.600000      26.40000
# max        9.000000      9.000000      40.200000      46.70000

# %% [markdown]
# ### 2.4. Data Visualization

# %% [markdown]
# #### 2.4.1. Biểu đồ thể hiện mối quan hệ giữa hai biến liên tục

# %% [markdown]
# > Thể hiện mối quan hệ giữ "Evaporation" và "Sunshine", "Rainfall" và "Cloud3mp"

# %%
fig=plt.figure(figsize=(20,8),facecolor='white')

gs=fig.add_gridspec(1,2)

ax=[_ for _ in range(2)]
ax[0]=fig.add_subplot(gs[0,0])
ax[1]=fig.add_subplot(gs[0,1])

ax[0].text(-1,15,"Relationship between Rainfall and Sunshine",fontsize=17,fontweight='normal', fontfamily='Verdana')

ax[1].text(-1,430,"Relationship between Rainfall and WindGustSpeed",fontsize=17,fontweight='normal', fontfamily='Verdana')

sns.lineplot(data=df_weather,x='Sunshine',y='Rainfall',ax=ax[0],color='#FFD700')
sns.scatterplot(data=df_weather,x='WindGustSpeed',y='Rainfall',ax=ax[1],color='#4B0082')

for i in range(2):
    
    ax[i].set_ylabel('Rainfall').set_rotation(0)
    ax[i].set_yticklabels('')
    ax[i].tick_params(axis='y',length=0)
    
    for direction in ['top','right','left']:
        ax[i].spines[direction].set_visible(False)
        
plt.tight_layout()
plt.show()

# %%
fig=plt.figure(figsize=(20,8),facecolor='white')

gs=fig.add_gridspec(1,2)

ax=[_ for i in range(2)]

ax[0]=fig.add_subplot(gs[0,0])
ax[1]=fig.add_subplot(gs[0,1])

ax[0].text(-1,15,"Relationship between Evaporation and Sunshine",fontsize=17,fontweight='normal', fontfamily='Verdana')

ax[1].text(-1,430,"Relationship between Rainfall and Cloud3mp",fontsize=17,fontweight='normal', fontfamily='Verdana')


for i in range(2):
    ax[i].set_yticklabels([])
    ax[i].tick_params(axis='y',length=0)
    
    for direction in ["top","right", 'left']:
        ax[i].spines[direction].set_visible(False)

sns.lineplot(data=df_weather,x='Sunshine',y='Evaporation',ax=ax[0],hue='RainTomorrow')
sns.scatterplot(data=df_weather,x='Cloud3pm',y='Rainfall',hue='RainTomorrow',ax=ax[1],palette='viridis',markers='o',alpha=0.3)
# Out:
# <Axes: xlabel='Cloud3pm', ylabel='Rainfall'>

# %% [markdown]
# #### 2.4.2. Biểu đồ Histogram

# %% [markdown]
# > Biểu đồ histogram "Rainfall" với bins = 100

# %%
sns.histplot(data = df_weather, x = 'Rainfall', bins = 100, kde = True);

# %% [markdown]
# > Biểu đồ histogram "MaxTemp" với bins = 100

# %%
sns.histplot(data = df_weather, x = 'MaxTemp', bins = 100, kde = True);

# %% [markdown]
# > biểu đồ boxplot và biểu đồ histogram cho Max Temp

# %%
fig, (ax_box, ax_hist) = plt.subplots(2, 
                                    sharex = True, 
                                    gridspec_kw = {'height_ratios': (.15, .85)}) 
 
sns.boxplot(x = df_weather['MaxTemp'], ax = ax_box)
sns.histplot(x = df_weather['MaxTemp'], ax = ax_hist, bins = 10, kde = True)
 
ax_box.set(xlabel = '') 
ax_hist.set(xlabel = 'MaxTemp')
ax_hist.set(ylabel = 'count')
# Out:
# [Text(0, 0.5, 'count')]

# %% [markdown]
# > Biểu đồ histogram xem tần suất cột "RainTomorrow" với hai giá tri Yes và No

# %%
sns.countplot(x = 'RainTomorrow', data = df_weather)
# Out:
# <Axes: xlabel='RainTomorrow', ylabel='count'>

# %% [markdown]
# #### 2.4.3. Line plot

# %% [markdown]
# > Kiểu dữ liệu của cột `Date` tháng hiện tại là object nên  sẽ chuyển đổi nó sang kiểu datetime để dễ dàng xử lý các ngày tháng. => Dễ dàng trong việc Trực quan hóa dữ liệu.

# %%
df_weather["Date"]=pd.to_datetime(df_weather["Date"])

df_weather["year"]=df_weather["Date"].dt.year
df_weather["month"]=df_weather["Date"].dt.month
df_weather["day"]=df_weather["Date"].dt.day

df_weather.drop("Date",axis=1,inplace=True)

# %%
sns.lineplot(x="day",y="MinTemp",hue="RainTomorrow",data=df_weather)
# Out:
# <Axes: xlabel='day', ylabel='MinTemp'>

# %%
sns.lineplot(x="day",y="MaxTemp",hue="RainTomorrow",data=df_weather)
# Out:
# <Axes: xlabel='day', ylabel='MaxTemp'>

# %%
sns.lineplot(x=df_weather["day"],y=(df_weather["MaxTemp"]-df_weather["MinTemp"]),hue=df_weather["RainTomorrow"])
# Out:
# <Axes: xlabel='day', ylabel='None'>

# %% [markdown]
# > => Từ đây ta thấy rằng có sự chênh lệnh giữa nhiệt độ

# %%
sns.lineplot(x=df_weather["day"],y=df_weather["Pressure3pm"],hue=df_weather["RainTomorrow"])
# Out:
# <Axes: xlabel='day', ylabel='Pressure3pm'>

# %%
sns.lineplot(x=df_weather["day"],y=df_weather["Pressure9am"],hue=df_weather["RainTomorrow"])
# Out:
# <Axes: xlabel='day', ylabel='Pressure9am'>

# %%
sns.lineplot(x=df_weather["day"],y=(df_weather["Pressure3pm"]-df_weather["Pressure9am"]),hue=df_weather["RainTomorrow"])
# Out:
# <Axes: xlabel='day', ylabel='None'>

# %% [markdown]
# > => Nhưng đối với Pressure thì không có sự chênh klệch

# %% [markdown]
# #### 2.4.5. Boxplot

# %% [markdown]
# > chúng ta có thể thấy được outliers trong dataset

# %%
sns.boxenplot(y="Rainfall",x="RainTomorrow",data=df_weather)
# Out:
# <Axes: xlabel='RainTomorrow', ylabel='Rainfall'>

# %%
sns.boxenplot(y="Evaporation",x="RainTomorrow",data=df_weather)
# Out:
# <Axes: xlabel='RainTomorrow', ylabel='Evaporation'>

# %%
sns.boxenplot(y="Sunshine",x="RainTomorrow",data=df_weather)
# Out:
# <Axes: xlabel='RainTomorrow', ylabel='Sunshine'>

# %%
sns.boxenplot(y="WindGustSpeed",x="RainTomorrow",data=df_weather)
# Out:
# <Axes: xlabel='RainTomorrow', ylabel='WindGustSpeed'>

# %% [markdown]
# > => WindGustSpeed, Sunshine và Rainfall ảnh hưởng đến khả năng có mưa

# %% [markdown]
# ### 2.5.Data Preprocessing

# %% [markdown]
# #### 2.5.1.Handle missing values

# %% [markdown]
# > Bây giờ chúng ta sẽ phân tích biến mục tiêu là `RainTomorrow`.

# %%
# Checking for the missing values in the target variable
df_weather['RainTomorrow'].isnull().sum()
# Out:
# 3267

# %% [markdown]
# > `RainTomorrow` có 3267 giá trị bị thiếu. Vì `RainTomorrow` sẽ được phân loại. Vì vậy, chúng ta phải loại bỏ các hàng có giá trị bị thiếu.

# %%
# Droping the missing values
df_weather = df_weather.dropna(subset = ['RainTomorrow'])

# %% [markdown]
# > Check missing values

# %%
print(df_weather.isnull().sum())
# Out:
# Location             0
# MinTemp            637
# MaxTemp            322
# Rainfall          1406
# Evaporation      60843
# Sunshine         67816
# WindGustDir       9330
# WindGustSpeed     9270
# WindDir9am       10013
# WindDir3pm        3778
# WindSpeed9am      1348
# WindSpeed3pm      2630
# Humidity9am       1774
# Humidity3pm       3610
# Pressure9am      14014
# Pressure3pm      13981
# Cloud9am         53657
# Cloud3pm         57094
# Temp9am            904
# Temp3pm           2726
# RainToday         1406
# RainTomorrow         0
# year                 0
# month                0
# day                  0
# dtype: int64

# %% [markdown]
# `Evaporation`, `Sunshine`, `Cloud9am` and `Cloud3pm` có các giá trị bị thiếu lớn, vì vậy trước tiên chúng ta xử lý các giá trị bị thiếu cho các tính năng này.

# %%
df_weather.drop(columns = ['Sunshine', 'Cloud9am', 'Cloud3pm','Evaporation'], axis = 1, inplace = True)

# %% [markdown]
# > Xử lí giá trị bị thiếu cho các biến phân loại

# %%
categorical_col = df_weather.select_dtypes('object').columns[:-1].to_list()
for col in categorical_col:
    df_weather[col].fillna(df_weather[col].mode()[0], inplace = True)
    df_weather[col].fillna(df_weather[col].mode()[0], inplace = True)

# %% [markdown]
# > Các biến còn lại thì điền giá trị trung vị

# %%
# Removing the missing values from the remaining numerical features as they are <10%.
numeric_col = ['MinTemp', 'MaxTemp', 'Rainfall','WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm',
                'Humidity9am','Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Temp9am', 'Temp3pm']
for col in numeric_col:
    df_weather[col].fillna(df_weather[col].median(), inplace = True)
df_weather.columns
# Out:
# Index(['Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'WindGustDir',
#        'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am',
#        'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am',
#        'Pressure3pm', 'Temp9am', 'Temp3pm', 'RainToday', 'RainTomorrow',
#        'year', 'month', 'day'],
#       dtype='object')

# %% [markdown]
# > Xoá các cột year, month ,day

# %%
df_weather.drop(columns = ['year', 'month', 'day'], axis = 1, inplace = True)

# %% [markdown]
# > Xử lý giá trị ngoại lai => Sử dụng IQR

# %%
def remove_outliers_iqr(df, column):
    Q1 = np.percentile(df[column], 25)
    Q3 = np.percentile(df[column], 75)
    iqr = Q3 - Q1
    lower_bound = Q1 - 1.5 * iqr
    upper_bound = Q3 + 1.5 * iqr
    df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df

# %% [markdown]
# > Sử dụng lên cột Rainfall và WinGustSpeed

# %%
print("Before removing outliers:", df_weather.shape)
df_weather = remove_outliers_iqr(df_weather, 'Rainfall')
df_weather = remove_outliers_iqr(df_weather, 'WindGustSpeed')
print("After removing outliers:", df_weather.shape)
# Out:
# Before removing outliers: (142193, 18)
# After removing outliers: (110246, 18)

# %% [markdown]
# #### 2.5.2 Data standardization

# %% [markdown]
# > Bây giờ dữ liệu đã sẵn sàng để xử lý trước, hãy chuyển đổi các biến phân loại thành One Hot Encoding

# %%
df_weather = pd.get_dummies(df_weather, drop_first = True).reset_index(drop = True)
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110246 entries, 0 to 110245
# Columns: 107 entries, MinTemp to RainTomorrow_Yes
# dtypes: bool(95), float64(12)
# memory usage: 20.1 MB

# %% [markdown]
# > Lấy các thuộc tính có giá trị liên tục

# %%
numeric_df = df_weather.select_dtypes(include=['float64', 'int64']).columns[:-1].to_list()
print(numeric_df)
# Out:
# ['MinTemp', 'MaxTemp', 'Rainfall', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Temp9am']

# %% [markdown]
# > Chuyển đổi các thuộc tính phân loại thành 0 / 1

# %%
categorical_col = [i for i in df_weather.columns if i not in numeric_df]
print(categorical_col)
for col in categorical_col:
    df_weather[col] = df_weather[col].astype(int)
# Out:
# ['Temp3pm', 'Location_Albany', 'Location_Albury', 'Location_AliceSprings', 'Location_BadgerysCreek', 'Location_Ballarat', 'Location_Bendigo', 'Location_Brisbane', 'Location_Cairns', 'Location_Canberra', 'Location_Cobar', 'Location_CoffsHarbour', 'Location_Dartmoor', 'Location_Darwin', 'Location_GoldCoast', 'Location_Hobart', 'Location_Katherine', 'Location_Launceston', 'Location_Melbourne', 'Location_MelbourneAirport', 'Location_Mildura', 'Location_Moree', 'Location_MountGambier', 'Location_MountGinini', 'Location_Newcastle', 'Location_Nhil', 'Location_NorahHead', 'Location_NorfolkIsland', 'Location_Nuriootpa', 'Location_PearceRAAF', 'Location_Penrith', 'Location_Perth', 'Location_PerthAirport', 'Location_Portland', 'Location_Richmond', 'Location_Sale', 'Location_SalmonGums', 'Location_Sydney', 'Location_SydneyAirport', 'Location_Townsville', 'Location_Tuggeranong', 'Location_Uluru', 'Location_WaggaWagga', 'Location_Walpole', 'Location_Watsonia', 'Location_Williamtown', 'Location_Witchcliffe', 'Location_Wollongong', 'Location_Woomera', 'WindGustDir_ENE', 'WindGustDir_ESE', 'WindGustDir_N', 'WindGustDir_NE', 'WindGustDir_NNE', 'WindGustDir_NNW', 'WindGustDir_NW', 'WindGustDir_S', 'WindGustDir_SE', 'WindGustDir_SSE', 'WindGustDir_SSW', 'WindGustDir_SW', 'WindGustDir_W', 'WindGustDir_WNW', 'WindGustDir_WSW', 'WindDir9am_ENE', 'WindDir9am_ESE', 'WindDir9am_N', 'WindDir9am_NE', 'WindDir9am_NNE', 'WindDir9am_NNW', 'WindDir9am_NW', 'WindDir9am_S', 'WindDir9am_SE', 'WindDir9am_SSE', 'WindDir9am_SSW', 'WindDir9am_SW', 'WindDir9am_W', 'WindDir9am_WNW', 'WindDir9am_WSW', 'WindDir3pm_ENE', 'WindDir3pm_ESE', 'WindDir3pm_N', 'WindDir3pm_NE', 'WindDir3pm_NNE', 'WindDir3pm_NNW', 'WindDir3pm_NW', 'WindDir3pm_S', 'WindDir3pm_SE', 'WindDir3pm_SSE', 'WindDir3pm_SSW', 'WindDir3pm_SW', 'WindDir3pm_W', 'WindDir3pm_WNW', 'WindDir3pm_WSW', 'RainToday_Yes', 'RainTomorrow_Yes']

# %% [markdown]
# > Chuẩn hoá rời rạc theo phương pháp zscore

# %%
scalar=StandardScaler()
df_weather_scale = pd.DataFrame(scalar.fit_transform(df_weather[numeric_df]), columns = numeric_df)

# %% [markdown]
# > Nối lại các thuộc tính kiểu dữ liệu số với các thuộc tính mang giá trị rời rạc

# %%
df_weather_final = pd.concat([df_weather_scale, df_weather[categorical_col]], axis = 1)

# %% [markdown]
# > Sự phân bố của biến mục tiêu

# %%
# Checking for the class imbalance
fig = plt.figure(figsize = (10, 6))
axis = sns.countplot(x = 'RainTomorrow_Yes', data = df_weather)
axis.set_title('Class Distribution for the target feature', size = 16)

for patch in axis.patches:
    axis.text(x = patch.get_x() + patch.get_width()/2, y = patch.get_height()/2,
            s = f"{np.round(patch.get_height()/len(df_weather)*100, 1)}%",
            ha = 'center', size = 40, rotation = 0, weight = 'bold' ,color = 'white')

axis.set_xlabel('Rain Tomorrow', size = 14)
axis.set_ylabel('Count', size = 14)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# > Correlation between variables

# %%
# Checking for the correlation between the numeric features
# Correlation between numeric variables
numeric_col = ['MinTemp', 'MaxTemp', 'Rainfall','WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm',
               'Humidity9am','Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Temp9am', 'Temp3pm']

fig=plt.figure(figsize=(16,12))
axis=sns.heatmap(df_weather[numeric_col].corr(), annot=True, linewidths=3, square=True, cmap='Blues', fmt=".0%")

axis.set_title('Correlation between the features', fontsize=16)
axis.set_xticklabels(numeric_col, fontsize=12)
axis.set_yticklabels(numeric_col, fontsize=12, rotation=0)
# Out:
# [Text(0, 0.5, 'MinTemp'),
#  Text(0, 1.5, 'MaxTemp'),
#  Text(0, 2.5, 'Rainfall'),
#  Text(0, 3.5, 'WindGustSpeed'),
#  Text(0, 4.5, 'WindSpeed9am'),
#  Text(0, 5.5, 'WindSpeed3pm'),
#  Text(0, 6.5, 'Humidity9am'),
#  Text(0, 7.5, 'Humidity3pm'),
#  Text(0, 8.5, 'Pressure9am'),
#  Text(0, 9.5, 'Pressure3pm'),
#  Text(0, 10.5, 'Temp9am'),
#  Text(0, 11.5, 'Temp3pm')]

# %% [markdown]
# > Tương quan chặt chẽ giữa
#
# `Temp3pm` and `MaxTemp`
#
# `Pressure3pm` and `Pressure9am`
#
# `Temp9am` and `MinTemp`
#
# `Temp9am` and `MaxTemp`
#
# `Temp3pm` and `Temp9am`
#
# > Chúng ta sẽ loại bỏ một trong các đặc điểm trong mỗi cặp để tránh hiện tượng đa cộng tuyến

# %%
columns_to_drop = ['Temp3pm', 'Pressure3pm', 'Temp9am']
df_weather_final.drop(columns=columns_to_drop, inplace=True)
df_weather_final.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'WindGustSpeed', 'WindSpeed9am',
#        'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am',
#        'Location_Albany',
#        ...
#        'WindDir3pm_S', 'WindDir3pm_SE', 'WindDir3pm_SSE', 'WindDir3pm_SSW',
#        'WindDir3pm_SW', 'WindDir3pm_W', 'WindDir3pm_WNW', 'WindDir3pm_WSW',
#        'RainToday_Yes', 'RainTomorrow_Yes'],
#       dtype='object', length=104)

# %% [markdown]
# ## 3. Building an artificial neural network model regression problem

# %% [markdown]
# ### 3.1. Divide data into training set and test set

# %%
x_train, x_test, y_train, y_test = train_test_split(df_weather_final.drop(columns=['MaxTemp']), 
                                                    df_weather_final['MaxTemp'], 
                                                    test_size=0.2, 
                                                    random_state=42)

# %% [markdown]
# ### 3.2 Model FNN for Maximum temperature prediction

# %%
# Creating the FNN
model = Sequential()
model.add(Dense(units=8, activation='relu', name='layer_1'))
model.add(Dense(units=8, activation='relu', name='layer_2'))
model.add(Dense(units=8, activation='relu', name='layer_3'))
model.add(Dense(units=1))

# %% [markdown]
# ### 3.3 Train FNN for regression problem

# %%
# Compiling the FNN
model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.0001), metrics=['mse'])
# Fitting the FNN to the Training set
model.fit(x_train, y_train, epochs=32, verbose=1)
# Out:
# Epoch 1/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.8586 - mse: 0.8586
# Epoch 2/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.2142 - mse: 0.2142
# Epoch 3/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1571 - mse: 0.1571
# Epoch 4/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1429 - mse: 0.1429
# Epoch 5/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.1345 - mse: 0.1345
# Epoch 6/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1302 - mse: 0.1302
# Epoch 7/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1272 - mse: 0.1272
# Epoch 8/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1248 - mse: 0.1248
# Epoch 9/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.1228 - mse: 0.1228
# Epoch 10/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1201 - mse: 0.1201
# Epoch 11/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.1182 - mse: 0.1182
# Epoch 12/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.1187 - mse: 0.1187
# Epoch 13/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.1180 - mse: 0.1180
# Epoch 14/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.1155 - mse: 0.1155
# Epoch 15/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1154 - mse: 0.1154
# Epoch 16/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1129 - mse: 0.1129
# Epoch 17/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1134 - mse: 0.1134
# Epoch 18/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1142 - mse: 0.1142
# Epoch 19/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.1129 - mse: 0.1129
# Epoch 20/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1117 - mse: 0.1117
# Epoch 21/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.1108 - mse: 0.1108
# Epoch 22/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1115 - mse: 0.1115
# Epoch 23/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1114 - mse: 0.1114
# Epoch 24/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1095 - mse: 0.1095
# Epoch 25/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1099 - mse: 0.1099
# Epoch 26/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.1103 - mse: 0.1103
# Epoch 27/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1097 - mse: 0.1097
# Epoch 28/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1083 - mse: 0.1083
# Epoch 29/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.1093 - mse: 0.1093
# Epoch 30/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1082 - mse: 0.1082
# Epoch 31/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1062 - mse: 0.1062
# Epoch 32/32
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1083 - mse: 0.1083

# %% [markdown]
# ### 3.4. Model Summary

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ layer_1 (Dense)                 │ (None, 8)              │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_2 (Dense)                 │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_3 (Dense)                 │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,957 (11.55 KB)
#  Trainable params: 985 (3.85 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,972 (7.71 KB)

# %% [markdown]
# ### 3.5 Predicting

# %%
result=model.predict(x_test)
# Out:
# 690/690 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# ### 3.6. Evaluating

# %%
# Tính và hiển thị MSE, R^2, MAE
mse = mean_squared_error(y_test, result)
r2 = r2_score(y_test, result)
mae = mean_absolute_error(y_test, result)

print(f"MSE: {mse}")
print(f"R^2 Score: {r2}")
print(f"MAE: {mae}")
# Out:
# MSE: 0.11021316356344524
# R^2 Score: 0.889648992140482
# MAE: 0.2518643388801752

# %% [markdown]
# ## 4. Building an artificial neural network model classification problem

# %% [markdown]
# ### 4.1. Divide data into training set and test set

# %%
x_train_class, x_test_class, y_train_class, y_test_class = train_test_split(df_weather_final.drop(columns=['RainTomorrow_Yes']), 
                                                    df_weather_final['RainTomorrow_Yes'], 
                                                    test_size=0.2, 
                                                    random_state=42)

# %% [markdown]
# ### 4.2 Model FNN for RainTomorrow classification

# %%
# Creating the FNN
model_class = Sequential()

model_class.add(Dense(units=8, activation='relu', name='layer_1'))
model_class.add(Dense(units=8, activation='relu', name='layer_2'))
model_class.add(Dense(units=8, activation='relu', name='layer_3'))
model_class.add(Dense(units=8, activation='relu', name='layer_4'))
model_class.add(Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ### 4.3 Train FNN for classification problem

# %%
# Compile mô hình
model_class.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])

# Định nghĩa callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_accuracy', save_best_only=True)  # Đổi tên thành 'best_model.keras'

# Huấn luyện mô hình với callbacks
history = model_class.fit(
    x_train_class, y_train_class,
    epochs=50,
    validation_data=(x_test_class, y_test_class),
    callbacks=[early_stopping, checkpoint]
)
# Out:
# Epoch 1/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.8440 - loss: 0.5096 - val_accuracy: 0.8454 - val_loss: 0.3673
# Epoch 2/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8492 - loss: 0.3544 - val_accuracy: 0.8454 - val_loss: 0.3477
# Epoch 3/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8521 - loss: 0.3415 - val_accuracy: 0.8656 - val_loss: 0.3376
# Epoch 4/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8672 - loss: 0.3303 - val_accuracy: 0.8682 - val_loss: 0.3319
# Epoch 5/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8677 - loss: 0.3288 - val_accuracy: 0.8701 - val_loss: 0.3283
# Epoch 6/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8721 - loss: 0.3196 - val_accuracy: 0.8712 - val_loss: 0.3255
# Epoch 7/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8732 - loss: 0.3195 - val_accuracy: 0.8717 - val_loss: 0.3237
# Epoch 8/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8765 - loss: 0.3132 - val_accuracy: 0.8721 - val_loss: 0.3223
# Epoch 9/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8758 - loss: 0.3155 - val_accuracy: 0.8735 - val_loss: 0.3212
# Epoch 10/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8750 - loss: 0.3143 - val_accuracy: 0.8737 - val_loss: 0.3199
# Epoch 11/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8755 - loss: 0.3138 - val_accuracy: 0.8735 - val_loss: 0.3189
# Epoch 12/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8751 - loss: 0.3132 - val_accuracy: 0.8739 - val_loss: 0.3181
# Epoch 13/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8766 - loss: 0.3118 - val_accuracy: 0.8746 - val_loss: 0.3172
# Epoch 14/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8756 - loss: 0.3131 - val_accuracy: 0.8749 - val_loss: 0.3166
# Epoch 15/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8774 - loss: 0.3091 - val_accuracy: 0.8753 - val_loss: 0.3160
# Epoch 16/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8756 - loss: 0.3107 - val_accuracy: 0.8750 - val_loss: 0.3154
# Epoch 17/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8781 - loss: 0.3068 - val_accuracy: 0.8747 - val_loss: 0.3150
# Epoch 18/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8775 - loss: 0.3089 - val_accuracy: 0.8754 - val_loss: 0.3143
# Epoch 19/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8810 - loss: 0.3029 - val_accuracy: 0.8753 - val_loss: 0.3137
# Epoch 20/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8772 - loss: 0.3086 - val_accuracy: 0.8753 - val_loss: 0.3135
# Epoch 21/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8778 - loss: 0.3078 - val_accuracy: 0.8755 - val_loss: 0.3128
# Epoch 22/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8775 - loss: 0.3069 - val_accuracy: 0.8757 - val_loss: 0.3125
# Epoch 23/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.8801 - loss: 0.3033 - val_accuracy: 0.8758 - val_loss: 0.3123
# Epoch 24/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8785 - loss: 0.3037 - val_accuracy: 0.8759 - val_loss: 0.3120
# Epoch 25/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8795 - loss: 0.3013 - val_accuracy: 0.8758 - val_loss: 0.3114
# Epoch 26/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8801 - loss: 0.3020 - val_accuracy: 0.8761 - val_loss: 0.3112
# Epoch 27/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8786 - loss: 0.3046 - val_accuracy: 0.8764 - val_loss: 0.3107
# Epoch 28/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8803 - loss: 0.3030 - val_accuracy: 0.8764 - val_loss: 0.3105
# Epoch 29/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.8804 - loss: 0.3026 - val_accuracy: 0.8766 - val_loss: 0.3101
# Epoch 30/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.8824 - loss: 0.2995 - val_accuracy: 0.8771 - val_loss: 0.3097
# Epoch 31/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8820 - loss: 0.2973 - val_accuracy: 0.8767 - val_loss: 0.3094
# Epoch 32/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8805 - loss: 0.3012 - val_accuracy: 0.8773 - val_loss: 0.3093
# Epoch 33/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8809 - loss: 0.2994 - val_accuracy: 0.8773 - val_loss: 0.3090
# Epoch 34/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8810 - loss: 0.3006 - val_accuracy: 0.8769 - val_loss: 0.3089
# Epoch 35/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8810 - loss: 0.3009 - val_accuracy: 0.8766 - val_loss: 0.3084
# Epoch 36/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8823 - loss: 0.2966 - val_accuracy: 0.8769 - val_loss: 0.3081
# Epoch 37/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8839 - loss: 0.2955 - val_accuracy: 0.8768 - val_loss: 0.3079
# Epoch 38/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8822 - loss: 0.2982 - val_accuracy: 0.8767 - val_loss: 0.3076
# Epoch 39/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8822 - loss: 0.2976 - val_accuracy: 0.8773 - val_loss: 0.3078
# Epoch 40/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8831 - loss: 0.2956 - val_accuracy: 0.8765 - val_loss: 0.3074
# Epoch 41/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8807 - loss: 0.3002 - val_accuracy: 0.8768 - val_loss: 0.3071
# Epoch 42/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8837 - loss: 0.2945 - val_accuracy: 0.8776 - val_loss: 0.3068
# Epoch 43/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8812 - loss: 0.2985 - val_accuracy: 0.8766 - val_loss: 0.3066
# Epoch 44/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8832 - loss: 0.2938 - val_accuracy: 0.8773 - val_loss: 0.3063
# Epoch 45/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8828 - loss: 0.2937 - val_accuracy: 0.8770 - val_loss: 0.3064
# Epoch 46/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8837 - loss: 0.2939 - val_accuracy: 0.8770 - val_loss: 0.3059
# Epoch 47/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8829 - loss: 0.2942 - val_accuracy: 0.8776 - val_loss: 0.3058
# Epoch 48/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8827 - loss: 0.2943 - val_accuracy: 0.8776 - val_loss: 0.3058
# Epoch 49/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8808 - loss: 0.2973 - val_accuracy: 0.8780 - val_loss: 0.3055
# Epoch 50/50
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8837 - loss: 0.2931 - val_accuracy: 0.8776 - val_loss: 0.3057

# %% [markdown]
# ### 4.4. Model Summary

# %%
model_class.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ layer_1 (Dense)                 │ (None, 8)              │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_2 (Dense)                 │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_3 (Dense)                 │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_4 (Dense)                 │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,173 (12.40 KB)
#  Trainable params: 1,057 (4.13 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2,116 (8.27 KB)

# %% [markdown]
# ### 4.5 Classifying

# %%
loss, accuracy = model_class.evaluate( x_test_class, y_test_class)
# Out:
#   1/690 ━━━━━━━━━━━━━━━━━━━━ 15s 23ms/step - accuracy: 0.9062 - loss: 0.3113
# 690/690 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step - accuracy: 0.8787 - loss: 0.3056

# %% [markdown]
# ### 4.6. Evaluating

# %%
print(f"Loss trên dữ liệu kiểm tra: {loss}")
print(f"Độ chính xác trên dữ liệu kiểm tra: {accuracy}")
# Out:
# Loss trên dữ liệu kiểm tra: 0.305502325296402
# Độ chính xác trên dữ liệu kiểm tra: 0.8779591917991638

# %%
# Vẽ đồ thị độ chính xác và hàm mất mát
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Dự đoán nhãn của dữ liệu kiểm tra
y_pred = model_class.predict(x_test_class)
y_pred_class = (y_pred > 0.5).astype(int)  # Chuyển các xác suất thành nhãn nhị phân

# Tính confusion matrix
cm = confusion_matrix(y_test_class, y_pred_class)
print(cm)
# Vẽ heatmap của confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 690/690 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step
# [[18164   478]
#  [ 2213  1195]]

# %%
# In báo cáo hiệu suất
print(classification_report(y_test_class, y_pred_class))

# Đồ thị hoặc trực quan hóa các giá trị F1 score, recall, accuracy
# Ví dụ: Vẽ bar chart của F1 score, recall, accuracy
f1 = f1_score(y_test_class, y_pred_class)
recall = recall_score(y_test_class, y_pred_class)
accuracy = accuracy_score(y_test_class, y_pred_class)

plt.figure(figsize=(8, 6))
labels = ['F1 Score', 'Recall', 'Accuracy']
values = [f1, recall, accuracy]
plt.bar(labels, values, color=['blue', 'green', 'orange'])
plt.title('Model Performance Metrics')
plt.ylabel('Score')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93     18642
#            1       0.71      0.35      0.47      3408
#
#     accuracy                           0.88     22050
#    macro avg       0.80      0.66      0.70     22050
# weighted avg       0.86      0.88      0.86     22050

# %%
# Tính false positive rate (fpr) và true positive rate (tpr)
fpr, tpr, thresholds = roc_curve(y_test_class, y_pred)

# Tính diện tích dưới đường cong ROC (AUC)
auc = roc_auc_score(y_test_class, y_pred)

# Vẽ ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='orange', label='ROC curve (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
